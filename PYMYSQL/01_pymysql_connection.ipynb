# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0

# %%
import pymysql

# %% [markdown]
# Connection with avien cloud

# %%
con=pymysql.connect(
    host='mysql-gaurav-hirulkargaurav348-6e84.h.aivencloud.com',
    user='avnadmin',
    password='AVNS_liKX8-67OO77oJC7wH4',
    port=26168,
    database='AI_ML_BATCH'
)
print("Connected Successfully")
# Out:
# Connected Successfully

# %%
curs=con.cursor()

# %%
curs.execute("select * from student ")
data=curs.fetchall()

for x in data:
  print(x)
# Out:
# (1, 'Gaurav', 'h@gmail.com', 23, 'AMRAVATI', None, None)
# (2, 'Ram', 'a@gmail.com', 200, 'AMRAVATI', None, None)
# (3, 'Sham', 's@gmail.com', 21, 'PUNE', None, None)
# (4, 'mithilesh', 'm@gmail.com', 100, 'AMRAVATI', 'male', 'CSE')
# (12, 'ABC', 'B@gmail.com', 22, 'AMRAVATI', 'Male', 'CSE')
# (13, 'MNO', 'K@gmail.com', 23, 'AMRAVATI', 'Male', 'IT')
