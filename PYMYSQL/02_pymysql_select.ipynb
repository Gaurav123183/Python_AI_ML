# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.13/dist-packages (1.2.0)

# %%
import pymysql

# %% [markdown]
# Connection with avien cloud

# %%
con=pymysql.connect(
    host='mysql-gaurav-hirulkargaurav348-6e84.h.aivencloud.com',
    port=26168,
    user='avnadmin',
    password='AVNS_liKX8-67OO77oJC7wH4',
    database='AI_ML_BATCH'

)

print("CONNECTED SUCCESSFULLY")
# Out:
# CONNECTED SUCCESSFULLY

# %%
curs=con.cursor()

# %%
curs.execute('Select * from demo')
data=curs.fetchall()


# print(data)
for x in data:
  print(x)
# Out:
# (1, 'Gaurav', 21, 'MALE', 'h@gmail.com', 232465753)
# (2, 'RAM', 22, 'MALE', 'a@gmail.com', 22465753)
# (3, 'sham', 21, 'Male', 's@gmail.com', 1212121)

# %% [markdown]
# C -> insert
# R -> select
# U -> Update
# D -> Delete
