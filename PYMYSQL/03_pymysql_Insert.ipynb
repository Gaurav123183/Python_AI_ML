# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.13/dist-packages (1.2.0)

# %%
import pymysql

# %%
curs=con.cursor()

# %%
con=pymysql.connect(
    host='mysql-gaurav-hirulkargaurav348-6e84.h.aivencloud.com',
    port=26168,
    user='avnadmin',
    password='AVNS_liKX8-67OO77oJC7wH4',
    database='AI_ML_BATCH'

)

print("Success")
# Out:
# Success

# %%
curs=con.cursor()

# %%
name=input("Enter your name : ")
age=int(input("Enter your age : "))
gender=input("Enter your Gender : ")
email=input("Enter your Email : ")
phone_no=int(input("Enter your number : "))



curs.execute(f"insert into demo(name,age,gender,email,phone_no) values('{name}',{age},'{gender}','{email}',{phone_no})")

con.commit()

con.close()
# Out:
# Enter your name : XYZ
# Enter your age : 23
# Enter your Gender : MALE
# Enter your Email : X@gmail.com
# Enter your number : 1234535
