# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.0 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
con= pymysql.connect(
    host='mysql-gaurav-hirulkargaurav348-6e84.h.aivencloud.com',
    port= 26168,
    password='AVNS_liKX8-67OO77oJC7wH4',
    user='avnadmin',
    database='AI_ML_BATCH'
)

print("Connected successfully")
# Out:
# Connected successfully

# %%
curs=con.cursor()

# %%
id=int(input("Enter ID : "))
curs.execute(f"update demo set age=43 where id={id}")
con.commit()
print("Data is updated")
# Out:
# Enter ID : 5
# Data is updated

# %%
##Just for practice -> this is not recommended
name=input("Enter Name : ")
curs.execute(f"update demo set gender='female' where name='{name}'")
con.commit()
print("Updated ")
# Out:
# Enter Name : sham
# Updated

# %%
name=input("Enter name : ")
id=int(input("Enter ID : "))
curs.execute(f"update demo set phone_no=932248 where name='{name}' and id={id}")
con.commit()
print("Updated")
# Out:
# Enter name : Gaurav
# Enter ID : 1
# Updated
