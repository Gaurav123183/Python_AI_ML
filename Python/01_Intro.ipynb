# %% [markdown]
# 1 > Python
# 2 -> mysql -> structured data base
#  window function
#  Indexes
#  virtual function
#  Joins
#  Key
#  Structure
#  Work
#  CRUD
#
#
# ---

# %% [markdown]
# Django -> backend
# login authentication
# Database
# mysql ->structured
#
#
# Rest Api -> API KEY
# Open ai -> api key
# 2 kind
#
#
# 1 baki logo ki use karenge
# 2 Khud ki api key -> PUT Get POST DELETE
# POSTMAN
#
#
# mongodb -> unstructured
#
# Pandas -> ML
# Numpy
# Matplotlib -> data visualization
# Seaborn
# |
# Data science
#
#
# Data
# Data clean
# Preprocessing
# Prediction
# visualization
#
# AI
# Open ai -> api key
# Deep Seek
# Gemini -> image create
# Azure
#
# Text to speech
# Speech To text
# sentimental
# summary analyse
# Image create
# generate text
# Tips
#
#
# RAG
# Basics
# Implement
