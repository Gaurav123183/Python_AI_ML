# %%
##variable
a=10
b=20
print(a, b)
# Out:
# 10 20

# %%
##Data type
##int
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
b= 2.23
print(type(b))
# Out:
# <class 'float'>

# %%
ans=True
print(type(ans))
# Out:
# <class 'bool'>

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %% [markdown]
# Type casting
# 1 Implict type casting
# 2 Explict type casting

# %%
a=10 ##-> int
b=2.2 ## -> float
c=a+b
print(c)
print(type(c))
## c int + float -> float
# Out:
# 12.2
# <class 'float'>

# %% [markdown]
# 2 explict

# %%
b="abc"
print(type(b))
# Out:
# <class 'str'>

# %%
a="10"
b=int(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 10
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Input / output

# %%
##int a;
##cin>>a;
##cout<<"Enter data"
##a=20

# %%
value=input("Enter the value : ")
print(value)
# Out:
# Enter the value : Xyz
# Xyz

# %%
value=int(input("Enter the value : "))
print(value, type(value))
# Out:
# Enter the value : 12
# 12 <class 'int'>

# %%
a="10"
b=20
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1052/3719095088.py in <cell line: 0>()
#       1 a="10"
#       2 b=20
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
value =int (input("Enter the value : "))
print(value , type(value))
# Out:
# Enter the value : 12
# 12 <class 'int'>

# %%
a=10
b=2.0
c="string"
d=True

# %%
a=int(input("enter the value"))
print(f"value is {a}")
# Out:
# enter the value12
# value is 12

# %% [markdown]
# f -> Formatted string

# %%
a=int(input("enter the value"))
b=int(input("enter the value"))
print(f"value is {a} , {b}")
# Out:
# enter the value12
# enter the value13
# value is 12 , 13

# %%
name = input("Bhai tera nam kya he : ")
print(f"Bhai ka name {name}")
# Out:
# Bhai tera nam kya he : Gaurav
# Bhai ka name Gaurav

# %%
a= int(input("enter value 1 : "))
b= int(input("enter value 2 : "))
print(a+b)
# Out:
# enter value 1 : 1
# enter value 2 : 2
# 3

# %%
a= int(input("enter value 1 : "))
b= int(input("enter value 2 : "))
c=a+b
print(c)
# Out:
# enter value 1 : 12
# enter value 2 : 13
# 25

# %%
a= int(input("enter value 1 : "))
b= int(input("enter value 2 : "))
print(f"Addition of {a} and {b} is {a+b}")
# Out:
# enter value 1 : 12
# enter value 2 : 34
# Addition of 12 and 34 is 46

# %%
name = "A"
print(f"|{name:<20} |")
print(f"|{name:>20} |")
print(f"|{name:^40} |")
# Out:
# |A                    |
# |                   A |
# |                   A                     |

# %%
name = "A"
print(f"|{name:*<20}|")
print(f"|{name:*>20}|")
print(f"|{name:*^40}|")
# Out:
# |A*******************|
# |*******************A|
# |*******************A********************|

# %%
a="25"
b=10
c=int(a)+b
print(c , type(c))
# Out:
# 35 <class 'int'>

# %%
a=input("enter the value")
b=input("enter the value")
c=int(a)
d=int(b)
print(c, d)
# Out:
# enter the value12
# enter the value13
# 12 13

# %%
a="5"
c=int(a)
b=5
print(f"multiplication {c*b}")
# Out:
# multiplication 25

# %%
a="*"
print(10*a)
# Out:
# **********

# %%
a=12
b="5"
print(type(b))
print(type(str(a)+b))
# Out:
# <class 'str'>
# <class 'str'>
