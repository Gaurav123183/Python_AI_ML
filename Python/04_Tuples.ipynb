# %%
t=(10)
t.append(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1872/3941722213.py in <cell line: 0>()
#       1 t=(10)
# ----> 2 t.append(20)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
t=(10,True,3.14,"string")
print(t)
# Out:
# (10, True, 3.14, 'string')

# %%
t=10,20,30
print(type(t))
# Out:
# <class 'tuple'>

# %%
t=(10,20,30,40,50)

# %%
print(t[0])
print(t[1])
print(t[2])
print(t[3])
# Out:
# 10
# 20
# 30
# 40

# %%
lst=[10,20,30]
lst[0]=200
print(lst)
# Out:
# [200, 20, 30]

# %%
t=(10,20,30,40,50) ##-.> immutable -> NO change

t[0]=200
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1872/4166124779.py in <cell line: 0>()
#       1 t=(10,20,30,40,50)
#       2
# ----> 3 t[0]=200
#       4 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=(10,20,[100,200,300],40)
###0.  1.      2.       3
print(t[2])
print("Tuple Before")
print(t)
t[2].append(400)
print("Tuple After")

print(t)
# Out:
# [100, 200, 300]
# Tuple Before
# (10, 20, [100, 200, 300], 40)
# Tuple After
# (10, 20, [100, 200, 300, 400], 40)

# %%
t=(10,20,30)
print(t[-1])
# Out:
# 30

# %%
t=(10,20)
s=(30,30)
z=t+s
print(z)
# Out:
# (10, 20, 30, 30)

# %%
lst=[1]
print(lst*5)
# Out:
# [1, 1, 1, 1, 1]

# %%
t=(1)
print(t*5)
# Out:
# 5

# %%
##memebership
t=(10,30,40)
print(10 in t)
print(50 in t )
# Out:
# True
# False

# %%
t=(10,20)
print(len(t))
# Out:
# 2

# %%
t=(5,4,3,2,1)
print(max(t))
print(min(t))
print(sum(t))
print(sum(t)/len(t)) ## -> avg
print(sorted(t))
# Out:
# 5
# 1
# 15
# 3.0
# [1, 2, 3, 4, 5]

# %%
## index -> tuple  -> index value
t=(5,4,3,2,1)
print(t.index(5))
print(t.index(4))
print(t.index(3))
# Out:
# 0
# 1
# 2

# %%
#packing and unpacking
t=(10,20,30)
a,b,c=t
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
#packing and unpacking
t=(10,20,30)
a,b=t
print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1872/406150982.py in <cell line: 0>()
#       1 #packing and unpacking
#       2 t=(10,20,30)
# ----> 3 a,b=t
#       4 print(a)
#       5 print(b)
#
# ValueError: too many values to unpack (expected 2)

# %%
#packing and unpacking
t=(10,20,30)
a,*b=t
print(a)
print(b)
# Out:
# 10
# [20, 30]

# %%
lst=[[1,2],[3,4]]
print(lst)
# Out:
# [[1, 2], [3, 4]]

# %%
t=((1,2),(3,4))
## 0     , 1
##(1, 2)
 # 0 , 1

 ## (3,4)
 ##  0,1
print(t[0][1])
#4
print(t[1][1])
print(t)
# Out:
# 2
# 4
# ((1, 2), (3, 4))

# %%
t=(10,20,30,40)
  # 0,1 , 2, 3
print(t[1:3:1])

print(t[2:])

print(t[ :3])
print(t[: :1])
print(t[ : : -1 ])

print(t[ : :-2])
print(t[: : 2])
# Out:
# (20, 30)
# (30, 40)
# (10, 20, 30)
# (10, 20, 30, 40)
# (40, 30, 20, 10)
# (40, 20)
# (10, 30)
