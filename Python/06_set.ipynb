# %%
s={10,20,30}
print(s)
# Out:
# {10, 20, 30}

# %%
print(s[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2249/287792665.py in <cell line: 0>()
# ----> 1 print(s[0])
#
# TypeError: 'set' object is not subscriptable

# %%
s={10,20,30,40,40,50,50}
print(s)
# Out:
# {50, 20, 40, 10, 30}

# %%
s=set([1,2,3,4])
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s={10, 3.14 , "string ", True}
print(s)
# Out:
# {True, 10, 3.14, 'string '}

# %%
s={10,20,30,40}
print(len(s))
# Out:
# 4

# %%
s={10,20,30,40}
print(100  in s )
# Out:
# False

# %%
s={10,20}
print(s)
s.add(30)
s.add(40)
s.add(50)
print(s)
# Out:
# {10, 20}
# {40, 10, 50, 20, 30}

# %%
s={1,2,3,4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
s={1,2,3,4}
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2249/2124671754.py in <cell line: 0>()
#       1 s={1,2,3,4}
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
s={1,2,3,4}
s.clear()
print(s)
# Out:
# set()

# %%
s={1,2}
s.update("Abc")
print(s)
# Out:
# {1, 2, 'b', 'c', 'A'}

# %%
sen ="ram and sham and xyz is playing"
print(set(sen.split()))
# Out:
# {'ram', 'sham', 'is', 'playing', 'xyz', 'and'}

# %%
sent="bannnanna"
print(set(sent))
# Out:
# {'a', 'b', 'n'}

# %%
lst=[1,2,3,4,5,5,6,6]
print((set(lst)))
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Mathematical operation -> set

# %%
a={1,2,3,4}
b={3,4,5,6}

# &
print(a&b)

# |
print(a|b)

# -
print(a-b)

print(b-a)
# ^ symmetric operator
print(a^b)
# Out:
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# {5, 6}
# {1, 2, 5, 6}

# %%
s={x*x for x in range (1,11)}
print(s)
# Out:
# {64, 1, 4, 36, 100, 9, 16, 49, 81, 25}

# %%
s={10 * x  for x in range (1,11)}
print(s)
# Out:
# {100, 70, 40, 10, 80, 50, 20, 90, 60, 30}

# %%
a=5
b=3
print(a&b)
print(a|b)
print(a^b)
## a=> 0 1 0 1
##b -> 0 0 1 1
       0 1 1 0
       8 4 2 1
# Out:
# 1
# 7
# 6
