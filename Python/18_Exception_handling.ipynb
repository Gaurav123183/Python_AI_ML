# %% [markdown]
# ZeroDivisionError

# %%
a=int(input("Enter the number : "))
b=int(input("Enter the number : "))
c=a/b
print(c)
# Out:
# Enter the number : 10
# Enter the number : 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2488/1148935262.py in <cell line: 0>()
#       1 a=int(input("Enter the number : "))
#       2 b=int(input("Enter the number : "))
# ----> 3 c=a/b
#       4 print(c)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ValueError

# %%
a=int(input("Enter the number : "))
b=int(input("Enter the number : "))
c=a/b
print(c)
# Out:
# Enter the number : 10
# Enter the number : abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2488/1148935262.py in <cell line: 0>()
#       1 a=int(input("Enter the number : "))
# ----> 2 b=int(input("Enter the number : "))
#       3 c=a/b
#       4 print(c)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# IndexError -> Outof the range error

# %%
nums=[10,20,30,40,50]
index=int(input("Enter the index : "))

print(nums[index])
# Out:
# Enter the index : 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2488/2595760680.py in <cell line: 0>()
#       2 index=int(input("Enter the index : "))
#       3
# ----> 4 print(nums[index])
#
# IndexError: list index out of range

# %% [markdown]
# TypeError -> string + integer

# %%
print("10"+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2488/2738465045.py in <cell line: 0>()
# ----> 1 print("10"+5)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# KeyError

# %%
dict={
    "name":"Gaurav",
    "age":21,
    "rollno":3,
    "section":"B"
}
key=input("Enter the Key : ")
print(dict[key])
# Out:
# Enter the Key : school
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2488/3483225973.py in <cell line: 0>()
#       6 }
#       7 key=input("Enter the Key : ")
# ----> 8 print(dict[key])
#
# KeyError: 'school'

# %% [markdown]
# Handling ZeroDivisionError

# %%
try:
  a=int(input("Enter 1st num : "))
  b=int(input("Enter 2st num : "))
  c=a/b
  print(c)
except ZeroDivisionError:
  print("It is a ZeroDivisionError")
finally:
  print("THis is finally block ")
# Out:
# Enter 1st num : 10
# Enter 2st num : 0
# It is a ZeroDivisionError
# THis is finally block

# %% [markdown]
# Handling value error

# %%
try:
  a=int(input("Enter 1st num : "))
  b=int(input("Enter 2st num : "))
  c=a/b
  print(c)
except ValueError:
  print("It is a ValueError")
finally:
  print("Finally block")
# Out:
# Enter 1st num : 10
# Enter 2st num : abc
# It is a ValueError
# Finally block

# %% [markdown]
# Handling Index error

# %%
num=[10,20,30,40]

try:
  index=int(input("Enter index : "))
  print(num[index])
except IndexError:
  print("It is a IndexError")
finally:
  print("Finally block")
# Out:
# Enter index : 10
# It is a IndexError
# Finally block

# %% [markdown]
# Handling type error

# %%
try:
  result="10"+5
  print(result)
except TypeError:
  print("It is a TypeError")
finally:
  print("Finally block")
# Out:
# 15
# Finally block

# %% [markdown]
# Handling Keyerror

# %%
dict={
    "name":"Xyz",
    "age":21,
    "rollno":3,
    "sec":"B",
    "marks":[10,20,30,40]
}


try :
  key=input("Enter key : ")
  print(dict[key])
except KeyError:
  print("This is keyerror")
finally:
  print("finally block")
# Out:
# Enter key : school
# This is keyerror
# finally block

# %%
try:
  a=int(input("Enter 1st num : "))
  b=int(input("Enter 2st num : "))
  c=a/b
  print(c)
except Exception as e:
  print(e)
# Out:
# Enter 1st num : 2
# Enter 2st num : abc
# invalid literal for int() with base 10: 'abc'

# %%
num=[10,20,30,40]
try:
  index=int(input("Enter index : "))
  print(num[index])
except Exception as e:
  print(e)
# Out:
# Enter index : 10
# list index out of range

# %% [markdown]
# Raise

# %%
try:
  age=15
  if age<18:
    raise ValueError("Age is less than 18")
except ValueError as e:
  print(e)
# Out:
# Age is less than 18

# %% [markdown]
# Hard Example-> withdraw

# %%
def withdraw(balance,amount):
  if balance<amount:
    raise ValueError("Insufficient Balance")
  else:
    return balance-amount



try :
  result=withdraw(1000,1500)
  print(result)
except Exception as e:
  print(e)
# Out:
# Insufficient Balance
