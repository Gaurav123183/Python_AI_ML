# %%
print(10)
print("Hi hello")
print(True)
# Out:
# 10
# Hi hello
# True

# %%
print(len("Hihello"))
print(len([10,20,30]))
print(len((1,2,3,4,5,6)))
# Out:
# 7
# 3
# 6

# %%
print(type(10))
print(type(True))
print(type("Hello"))
print(type([10,20,30,40]))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'str'>
# <class 'list'>
